# %%
# !pip install FlightRadarAPI
# Out:
# ...
#   Using cached requests-2.31.0-py3-none-any.whl.metadata (4.6 kB)
# ...
#   Using cached charset_normalizer-3.3.2-cp312-cp312-win_amd64.whl.metadata (34 kB)
# ...
#   Using cached idna-3.6-py3-none-any.whl.metadata (9.9 kB)
# ...
#   Using cached urllib3-2.2.1-py3-none-any.whl.metadata (6.4 kB)
# ...
#   Using cached certifi-2024.2.2-py3-none-any.whl.metadata (2.2 kB)
# ...
#    ---------------------------------------- 0.0/357.3 kB ? eta -:--:--
#    ---- ---------------------------------- 41.0/357.3 kB 991.0 kB/s eta 0:00:01
#    ------------------ --------------------- 163.8/357.3 kB 2.5 MB/s eta 0:00:01
#    ---------------------------- ----------- 256.0/357.3 kB 2.3 MB/s eta 0:00:01
#    -------------------------------------- - 348.2/357.3 kB 2.2 MB/s eta 0:00:01
#    ---------------------------------------- 357.3/357.3 kB 1.7 MB/s eta 0:00:00
# Using cached requests-2.31.0-py3-none-any.whl (62 kB)
# Using cached certifi-2024.2.2-py3-none-any.whl (163 kB)
# ...

# %%
from FlightRadar24 import FlightRadar24API
fr_api = FlightRadar24API()

# %%
flights = fr_api.get_flights('AAL')

# %%
flights[0]
# Out:
# <(B77W) N732AN - Altitude: 0 - Ground Speed: 18 - Heading: 2>

# %%
flights[0]

# %%
airports = fr_api.get_airports()

# %%
fr_api.get_airport_details('LEBL', page=2)
# Out:
# {'airport': {'pluginData': {'details': {'name': 'Barcelona El Prat Airport',
#     'code': {'iata': 'BCN', 'icao': 'LEBL'},
#     'delayIndex': {'arrivals': 0.42, 'departures': 1.75},
#     'stats': {'arrivals': {'delayIndex': 0.42,
#       'delayAvg': 5,
#       'percentage': {'delayed': 0.14, 'canceled': 0, 'trend': 'down'},
#       'recent': {'delayIndex': 0.42,
#        'delayAvg': 5,
#        'percentage': {'delayed': 0.14, 'canceled': 0, 'trend': 'down'},
#        'quantity': {'onTime': 36, 'delayed': 6, 'canceled': 0}},
#       'today': {'percentage': {'delayed': 0.04, 'canceled': 0},
#        'quantity': {'onTime': 133, 'delayed': 18, 'canceled': 2}},
#       'yesterday': {'percentage': {'delayed': 0.13, 'canceled': 0.02},
#        'quantity': {'onTime': 373, 'delayed': 58, 'canceled': 10}},
#       'tomorrow': {'percentage': {'canceled': 0},
#        'quantity': {'canceled': 0}}},
#      'departures': {'delayIndex': 1.75,
#       'delayAvg': 21,
# ...

# %%
airports[0].get_airport_details
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 airports[0].get_airport_details
#
# AttributeError: 'Airport' object has no attribute 'get_airport_details'

# %%
flights[0].
# Out:
# <(B77W) N732AN - Altitude: 0 - Ground Speed: 18 - Heading: 2>

# %%
flight_details = fr_api.get_flight_details(flights[0])
flight_details
# Out:
# {'identification': {'id': '345d46ee',
#   'row': 5481009949,
#   'number': {'default': 'AA293', 'alternative': None},
#   'callsign': 'AAL293'},
#  'status': {'live': False,
#   'text': 'Landed 06:02',
#   'icon': 'green',
#   'estimated': None,
#   'ambiguous': False,
#   'generic': {'status': {'text': 'landed',
#     'color': 'green',
#     'type': 'arrival'},
#    'eventTime': {'utc': 1710496958, 'local': 1710482558}}},
#  'level': 'limited',
#  'promote': False,
#  'aircraft': {'model': {'code': 'B77W', 'text': 'Boeing 777-323(ER)'},
#   'countryId': 236,
#   'registration': 'N732AN',
#   'age': None,
#   'msn': None,
#   'images': {'thumbnails': [{'src': 'https://cdn.jetphotos.com/200/5/922863_1705488463_tb.jpg?v=0',
#      'link': 'https://www.jetphotos.com/photo/11213146',
#      'copyright': 'Ernest Leung',
#      'source': 'Jetphotos'},
#     {'src': 'https://cdn.jetphotos.com/200/5/869743_1704905830_tb.jpg?v=0',
#      'link': 'https://www.jetphotos.com/photo/11205041',
# ...
